# %%
# !pip install pandas

# %%
import pandas as pd
series1 = pd.Series([10,20,30])
print(series1)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
series2 = pd.Series(["kavi","shyam","ravi"], index=[1,5,3])
print(series2)
# Out:
# 1     kavi
# 5    shyam
# 3     ravi
# dtype: object

# %%
import numpy as np
import pandas as pd
array1 = np.array([1,2,3,4])
series3 = pd.Series(array1)
print(series3)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
series4 = pd.Series(array1, index = ["jan", "feb", "mar", "apr"])
print(series4)
# Out:
# jan    1
# feb    2
# mar    3
# apr    4
# dtype: int32

# %%
dict1 = {'India': 'NewDelhi', 'UK': 'London', 'Japan': 'Tokyo'}
print(dict1)
{'India': 'NewDelhi', 'UK': 'London', 'Japan': 'Tokyo'}
# Out:
# {'India': 'NewDelhi', 'UK': 'London', 'Japan': 'Tokyo'}
# {'India': 'NewDelhi', 'UK': 'London', 'Japan': 'Tokyo'}

# %%
series8 = pd.Series(dict1)
print(series8)
# Out:
# India    NewDelhi
# UK         London
# Japan       Tokyo
# dtype: object

# %%
dict1 = {'India': 'NewDelhi', 'UK': 'London', 'Japan': 'Tokyo'}
print(dict1)
# Out:
# {'India': 'NewDelhi', 'UK': 'London', 'Japan': 'Tokyo'}

# %%
series8 = pd.Series(dict1)
print(series8)
# Out:
# India    NewDelhi
# UK         London
# Japan       Tokyo
# dtype: object

# %%
seriesMnths = pd.Series([2,3,4],index=["feb","march","apr"])
seriesMnths["march"]
# Out:
# 3

# %%
seriesCapCntry = pd.Series(['newdelhi','washingtonDC','london','paris'], index= ['india','usa','uk','france'])
seriesCapCntry
# Out:
# india         newdelhi
# usa       washingtonDC
# uk              london
# france           paris
# dtype: object

# %%
import numpy as np
import pandas as pd

seriesTenTwenty=pd.Series(np.arange(10,20, 1 ))
print(seriesTenTwenty)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int32

# %%
seriesTenTwenty.head(2)
# Out:
# 0    10
# 1    11
# dtype: int32

# %%
seriesTenTwenty.count()
# Out:
# 10

# %%
seriesTenTwenty.tail(2)
# Out:
# 8    18
# 9    19
# dtype: int32

# %%
seriesA=pd.Series([1,2,3,4,5], index =['a' ,'b' ,'c', 'd', 'e'])
seriesA
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
seriesB = pd.Series([10,20,-10,-50,100],
index = ['z', 'y', 'a', 'c', 'e'])
seriesB
# Out:
# z     10
# y     20
# a    -10
# c    -50
# e    100
# dtype: int64

# %%
seriesA+seriesB
# Out:
# z     20
# y     40
# a    -20
# c   -100
# e    200
# dtype: int64

# %%
seriesA-seriesB
# Out:
# z    0
# y    0
# a    0
# c    0
# e    0
# dtype: int64

# %%
seriesA*seriesB
# Out:
# z      100
# y      400
# a      100
# c     2500
# e    10000
# dtype: int64

# %%
import numpy as np
array1 = np.array([10,20,30])
array2 = np.array([100,200,300])
array3 = np.array([-10,-20,-30,-40])
dframe4 = pd.DataFrame(array1)
dframe4
# Out:
#     0
# 0  10
# 1  20
# 2  30

# %%
import numpy as np
array1 = np.array([10,20,30])
array2 = np.array([100,200,300])
array3 = np.array([-10,-20,-30,-40])
dframe4 = pd.DataFrame(array2)
dframe4
# Out:
#      0
# 0  100
# 1  200
# 2  300

# %%
listdict = [{'a':10, 'b':20,}, {'a':5, 'b':10, 'c':20}]
dframelistdict = pd.DataFrame(listdict)
dframelistdict
# Out:
#     a   b     c
# 0  10  20   NaN
# 1   5  10  20.0

# %%
seriesA = pd.Series([1,2,3,4,5], index = ['a', 'b', 'c', 'd', 'e'])
seriesB = pd.series([1000,2000,-1000,-5000,1000], index = ['a', 'b', 'c', 'd', ''])

# %%
import pandas as pd
resultsheet={"Arnab" : pd.Series([90,91,97], index = ['math','science', 'hindi']),
"goldi" : pd.Series([92,81,96], index = ['math','science', 'hindi']),
"prakhar" : pd.Series([89,91,95], index = ['math','science', 'hindi']),
"puja" : pd.Series([90,85,88], index = ['math','science', 'hindi']),
"arham" : pd.Series([88,85,99], index = ['math','science', 'hindi'])}
ResultDF =  pd.DataFrame(resultsheet)
ResultDF
# Out:
#          Arnab  goldi  prakhar  puja  arham
# math        90     92       89    90     88
# science     91     81       91    85     85
# hindi       97     96       95    88     99

# %%
ResultDF['jimmy']=[89,78,76]
ResultDF
# Out:
#          Arnab  goldi  prakhar  puja  arham  jimmy
# math        90     92       89    90     88     89
# science     91     81       91    85     85     78
# hindi       97     96       95    88     99     76

# %%
ResultDF.loc['English'] = [85, 86, 76, 89, 45, 89]
ResultDF
# Out:
#          Arnab  goldi  prakhar  puja  arham  jimmy
# math        90     92       89    90     88     89
# science     91     81       91    85     85     78
# hindi       97     96       95    88     99     76
# English     85     86       76    89     45     89

# %%
ResultDF = ResultDF.drop('science', axis=0)
ResultDF
# Out:
#          Arnab  goldi  prakhar  puja  arham  jimmy
# math        90     92       89    90     88     89
# hindi       97     96       95    88     99     76
# English     85     86       76    89     45     89

# %%
ResultDF = ResultDF.drop(['puja','arham'], axis=1)
ResultDF
# Out:
#          Arnab  goldi  prakhar  jimmy
# math        90     92       89     89
# hindi       97     96       95     76
# English     85     86       76     89

# %%
ResultDF = ResultDF.rename({'math':'sub1', 'English':'sub3' ,'hindi':'sub4'}, axis = 'index')
print(ResultDF)
# Out:
#       Arnab  goldi  prakhar  jimmy
# sub1     90     92       89     89
# sub4     97     96       95     76
# sub3     85     86       76     89

# %%
ResultDF.loc['sub3']
# Out:
# Arnab      85
# goldi      86
# prakhar    76
# jimmy      89
# Name: sub3, dtype: int64

# %%
ResultDF.loc['sub1': 'sub4']
# Out:
#       Arnab  goldi  prakhar  jimmy
# sub1     90     92       89     89
# sub4     97     96       95     76

# %%
import pandas as pd


df3 = pd.read_csv("C:\\Users\\divya\\OneDrive\\Desktop\\netflix_titles.csv")
df3
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8799   s8803    Movie                 Zodiac    David Fincher
# 8800   s8804  TV Show            Zombie Dumb              NaN
# 8801   s8805    Movie             Zombieland  Ruben Fleischer
# 8802   s8806    Movie                   Zoom     Peter Hewitt
# 8803   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df3.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        '@dropdown'],
#       dtype='object')

# %%
df1['category'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22364\3864919827.py in ?()
# ----> 1 df1['director'].value_count()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
df1.sort_values([])
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8799   s8803    Movie                 Zodiac    David Fincher
# 8800   s8804  TV Show            Zombie Dumb              NaN
# 8801   s8805    Movie             Zombieland  Ruben Fleischer
# 8802   s8806    Movie                   Zoom     Peter Hewitt
# 8803   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df1.drop_duplicates(subset=['director','country']).shape
# Out:
# (5177, 13)

# %%
hello=df1.groupby('country')
country
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 hello=df1.groupby('country')
#       2 country
#
# NameError: name 'df1' is not defined

# %%
df1 = pd.read_csv("C:\\Users\\divya\\OneDrive\\Desktop\\Sample - Superstore.csv",encoding='latin-1')
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df1['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
hello = df1.groupby("Category")
hello

# %%
len(df1)
# Out:
# 9994

# %%
hello.size()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
import pandas as pd
df2=pd.read_csv("data health.csv")
df2
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df2.rename(columns={'Duration': 'timing'})
# Out:
#      timing  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# ..      ...    ...       ...       ...
# 164      60    105       140     290.8
# 165      60    110       145     300.0
# 166      60    115       145     310.2
# 167      75    120       150     320.4
# 168      75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df2.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Duration  Pulse  Maxpulse  Calories
# firstEntry         60    110       130     409.1
# secondEntry        60    117       145     479.0
# 2                  60    103       135     340.0
# 3                  45    109       175     282.4
# 4                  45    117       148     406.0
# ...               ...    ...       ...       ...
# 164                60    105       140     290.8
# 165                60    110       145     300.0
# 166                60    115       145     310.2
# 167                75    120       150     320.4
# 168                75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
pd.concat([df2,df1])
# Out:
#       Duration  Pulse  Maxpulse  Calories  Row ID        Order ID  Order Date  \
# 0         60.0  110.0     130.0     409.1     NaN             NaN         NaN
# 1         60.0  117.0     145.0     479.0     NaN             NaN         NaN
# 2         60.0  103.0     135.0     340.0     NaN             NaN         NaN
# 3         45.0  109.0     175.0     282.4     NaN             NaN         NaN
# 4         45.0  117.0     148.0     406.0     NaN             NaN         NaN
# ...        ...    ...       ...       ...     ...             ...         ...
# 9989       NaN    NaN       NaN       NaN  9990.0  CA-2014-110422   1/21/2014
# 9990       NaN    NaN       NaN       NaN  9991.0  CA-2017-121258   2/26/2017
# 9991       NaN    NaN       NaN       NaN  9992.0  CA-2017-121258   2/26/2017
# 9992       NaN    NaN       NaN       NaN  9993.0  CA-2017-121258   2/26/2017
# 9993       NaN    NaN       NaN       NaN  9994.0  CA-2017-119914  05-04-2017
#
# ...

# %%
df2.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df1.join(df2)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...
